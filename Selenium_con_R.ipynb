# %% [markdown]
# # Web Scraping con R sobre Selenium para páginas dinámicas

# %% [markdown]
# **Selenium** es un entorno de pruebas de software para aplicaciones basadas en la web. Selenium provee una herramienta de grabar/reproducir para crear pruebas sin usar un lenguaje de scripting para pruebas (Selenium IDE). Selenium permite escribir pruebas en un amplio número de lenguajes de programación populares como **Java**,**C#**,**Ruby**,**Groovy**,**Perl**,**PHP**, **Python** y **R**. Las pruebas pueden ejecutarse entonces usando la mayoría de los **navegadores web** modernos en diferentes sistemas operativos como **Windows**, **Linux** y **OSX**.

# %% [markdown]
# Para instalar [selenium](https://docs.seleniumhq.org/) sigue los siguientes paso:
# 1. Ir a [selenium](https://docs.seleniumhq.org/).
# 2. Luego ir a Download y descargar.
# 3. Luego descargar el Servidor de Selenium Standalone donde dice (Download version [3.12.0](https://goo.gl/tbd1NS))
# 4. Luego de descagar el Servidor, ir abajo a los lenguajes de programación donde dice ([R](https://github.com/ropensci/RSelenium) by John Harrison)
# 5. Por último instalar y configurar las herramientas.
# 6. Recordar que Selenium es básicamente para Firefox, aunque también sirve para Chrome.

# %% [markdown]
# ## Instalación de RSelenium en R

# %% [markdown]
# Seguir los paso del siguiente enlace para instalar [RSelenium](https://github.com/ropensci/RSelenium).

# %% [markdown]
# ## RSelenium: Básico

# %% [markdown]
# Seguir los pasos del siguiente enlace para correr el servidor [link](https://ropensci.github.io/RSelenium/articles/RSelenium-basics.html#how-do-i-get-the-selenium-server-stand-alone-binary).

# %% [markdown]
# ## Prueba básica de RSelenium con R

# %%
# Paquetes necesarios para correr 
library(RSelenium)
library(seleniumPipes)
library(jsonlite)
library(xml2)
library(magrittr)
library(webdriver)
library(httr)
library(rvest)
library(XML)
library(xml2)
library(XML2R)

# %% [markdown]
# Para correr el servidor Standalone de Selenium poner en el promt de comandos (cmd) la siguiente línea apuntando al directorio donde este guardado el selenium-server-standalone-3.12.0.jar
#
# 1. Mirar el directorio donde este guardado el selenium-server-standalone-3.12.0
# 2. Luego abrir el promt de comandos (cmd).
# 3. copiar: java -jar selenium-server-standalone-3.12.0.jar
# 4. Luego ir al R y establecer la conexión con el servidor.

# %%
# para correr el servidor Standalone de Selenium poner en el promt de comandos la siguiente línea apuntando al 
# directorio donde este guardado el selenium-server-standalone-3.12.0.jar
# java -jar selenium-server-standalone-3.12.0.jar
# shell('java -jar selenium-server-standalone-3.12.0.jar')

# %% [markdown]
# Luego para establecer la conexión desde R con el servidor debemos utilizar la función de $remoteDriver$ del paquete $RSelenium$.

# %% [markdown]
# $RSelenium::remoteDriver$ cuenta con los siguiente parámetros:
#
# - $remoteServerAddr:$ Es un objeto $"character"$ que sirve para conectarse con un servidor remoto por medio de la $ip$, ya que por defecto es $"localhost"$.
# - $port:$ Es un objeto $"numeric"$ con el puerto del servidor remoto para la conexión.
# - $browserName:$ Es un objeto $"character"$. Con el nombre del navegador a usar podría ser uno de: **chrome, firefox, htmlunit, internet explorer, iphone**.
# - $path:$ Camino base URL para comando sobre el servidor remoto. Por defecto **"/wd/hub"**.
# - $version:$ Es un objeto $"character"$. La versión del navegador, o la cadena vacía si es desconocido.
# - $platform:$ Es un objeto $"character"$. Una clave que especifica en qué plataforma se está ejecutando el navegador. Este valor debe ser uno de WINDOWS | XP | VISTA | MAC | LINUX | UNIX. Al solicitar una nueva sesión, el cliente puede especificar CUALQUIERA para indicar que se puede usar cualquier plataforma disponible.
# - $javascript:$ Es un objeto $"logical"$. Si la sesión admite la ejecución de JavaScript proporcionado por el usuario en el contexto de la página actual.
# - $nativeEvents:$ Es un objeto $"logical"$. Si la sesión admite eventos nativos. $n$ Las interacciones de usuario avanzado de WebDriver se proporcionan simulando los eventos de Javascript directamente (es decir, eventos sintéticos) o permitiendo que el navegador genere los eventos de Javascript (es decir, eventos nativos). Los eventos nativos simulan mejor las interacciones del usuario.
# - $serverURL:$ Es un objeto $"character"$. URL del servidor remoto al que se envían las solicitudes JSON.
# - $sessionInfo$ Es un objeto $"list"$. Una lista que contiene información sobre las sesiones.
#
# Para mayor información puedes visitar las siguientes páginas: [Descarga](https://cran.r-project.org/src/contrib/Archive/RSelenium/), [Manual1](https://ropensci.github.io/RSelenium/articles/RSelenium-basics.html), [Manual2](https://github.com/ropensci/RSelenium), [Manual3](https://ropensci.org/tutorials/rselenium_tutorial/), [Manual4](https://www.r-bloggers.com/rselenium-a-wonderful-tool-for-web-scraping/).

# %% [markdown]
# Existen unos métodos para la ejecutar con la función $remoteDriver$.
#
# - $navigate(url):$ Navega a una url determinada.
# - $open(silent = FALSE):$ Envíe una solicitud al servidor remoto para crear una instancia del navegador.
# - $refresh():$ Recarga la página actual.

# %% [markdown]
# ## Ejemplo básico con firefox con selenium

# %%
###### Con Firefox #############
# Sirve para conectarse al servidor con firefox
remDr <- remoteDriver(remoteServerAddr = "localhost", browserName="firefox", port= 4444)
remDr$open() # open web browser
# Out:
# [1] "Connecting to remote server"
# $acceptInsecureCerts
# [1] FALSE
#
# $browserName
# [1] "firefox"
#
# $browserVersion
# [1] "60.0.2"
#
# $`moz:accessibilityChecks`
# [1] FALSE
#
# $`moz:headless`
# [1] FALSE
#
# $`moz:processID`
# [1] 16652
#
# $`moz:profile`
# [1] "C:\\Users\\Johan Ruiz\\AppData\\Local\\Temp\\rust_mozprofile.0ZBas0rreB2f"
#
# $`moz:useNonSpecCompliantPointerOrigin`
# [1] FALSE
#
# $`moz:webdriverClick`
# [1] TRUE
#
# $pageLoadStrategy
# [1] "normal"
#
# $platformName
# [1] "windows_nt"
#
# $platformVersion
# [1] "10.0"
#
# $rotatable
# [1] FALSE
#
# $timeouts
# $timeouts$implicit
# [1] 0
#
# $timeouts$pageLoad
# [1] 300000
#
# $timeouts$script
# [1] 30000
#
#
# $webdriver.remote.sessionid
# [1] "d4eb0c3f-65d7-4a89-8704-b2745efd4a22"
#
# $id
# [1] "d4eb0c3f-65d7-4a89-8704-b2745efd4a22"

# %%
# Vamos ha realizar un llamado a la Firefox de Mis Marcadores Colombia liga aguila 
url = 'https://www.mismarcadores.com/futbol/colombia/liga-aguila/'
remDr$navigate(url)

# %%
# Vamos ha realizar un llamado a la Firefox de Mis Marcadores Colombia liga aguila 
url = 'https://www.mismarcadores.com/futbol/colombia/'
remDr$navigate(url)

# %%
# Sirve para abrir el navegador
remDr$open()

# %%
# Sirve para refrescar la página
remDr$refresh()

# %%
# Sirve para ir a la página anterior
remDr$goBack()

# %%
# Sirve para ir a la página siguiente
remDr$goForward()

# %%
# Sirve para ver la URL actual
remDr$getCurrentUrl()
# Out:
# [[1]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/"

# %%
# Obtiene el título de la página
remDr$getTitle()
# Out:
# [[1]]
# [1] "Resultados Liga Águila 2018, Fútbol Colombia - MisMarcadores.com"

# %%
# Sirve para obtener los cookies
# Recupere todas las cookies visibles para la página actual. 
# Cada cookie se devolverá como una lista con los siguientes nombres y tipos de valores:
# name:character
# value:character
# path:character
# domain:character
# secure:logical
remDr$getAllCookies()
# Out:
# [[1]]
# [[1]]$name
# [1] "fonce_current_session"
#
# [[1]]$value
# [1] "0"
#
# [[1]]$path
# [1] "/"
#
# [[1]]$domain
# [1] "www.mismarcadores.com"
#
# [[1]]$expiry
# [1] 1529533197
#
# [[1]]$secure
# [1] FALSE
#
# [[1]]$httpOnly
# [1] FALSE
#
#
# [[2]]
# [[2]]$name
# [1] "fonce_current_day"
#
# [[2]]$value
# [1] "0,2018-06-20"
#
# [[2]]$path
# [1] "/"
#
# [[2]]$domain
# [1] "www.mismarcadores.com"
#
# [[2]]$expiry
# NULL
#
# [[2]]$secure
# [1] FALSE
#
# [[2]]$httpOnly
# [1] FALSE
#
#
# [[3]]
# [[3]]$name
# [1] "fonce_current_user"
#
# [[3]]$value
# [1] "0"
#
# [[3]]$path
# [1] "/"
#
# [[3]]$domain
# [1] "www.mismarcadores.com"
#
# [[3]]$expiry
# [1] 1533851397
#
# [[3]]$secure
# [1] FALSE
#
# [[3]]$httpOnly
# [1] FALSE
#
#
# [[4]]
# [[4]]$name
# [1] "_ga"
#
# [[4]]$value
# [1] "GA1.2.403742446.1529531398"
#
# [[4]]$path
# [1] "/"
#
# [[4]]$domain
# [1] ".mismarcadores.com"
#
# [[4]]$expiry
# [1] 1592603397
#
# [[4]]$secure
# [1] FALSE
#
# [[4]]$httpOnly
# [1] FALSE
#
#
# [[5]]
# [[5]]$name
# [1] "_gid"
#
# [[5]]$value
# [1] "GA1.2.1347065808.1529531398"
#
# [[5]]$path
# [1] "/"
#
# [[5]]$domain
# [1] ".mismarcadores.com"
#
# [[5]]$expiry
# [1] 1529617797
#
# [[5]]$secure
# [1] FALSE
#
# [[5]]$httpOnly
# [1] FALSE
#
#
# [[6]]
# [[6]]$name
# [1] "_gat_UA-207011-10"
#
# [[6]]$value
# [1] "1"
#
# [[6]]$path
# [1] "/"
#
# [[6]]$domain
# [1] ".mismarcadores.com"
#
# [[6]]$expiry
# [1] 1529531457
#
# [[6]]$secure
# [1] FALSE
#
# [[6]]$httpOnly
# [1] FALSE

# %%
# Obtiene la possición de la página en el computador
remDr$getWindowPosition()
# Out:
# $height
# [1] 28
#
# $width
# [1] 160
#
# $x
# [1] -32000
#
# $y
# [1] -32000

# %%
# Recuperar el identificador de ventana actual.
remDr$getWindowHandles()
# Out:
# [[1]]
# [1] "4294967297"

# %%
# Consulta el estado actual del servidor. Todas las implementaciones del servidor deben devolver dos objetos 
# básicos que describen la plataforma actual del servidor y cuándo se creó el servidor.
remDr$getStatus()
# Out:
# $ready
# [1] TRUE
#
# $message
# [1] "Server is running"
#
# $build
# $build$revision
# [1] "7c6e0b3"
#
# $build$time
# [1] "2018-05-08T15:15:08.936Z"
#
# $build$version
# [1] "3.12.0"
#
#
# $os
# $os$arch
# [1] "amd64"
#
# $os$name
# [1] "Windows 10"
#
# $os$version
# [1] "10.0"
#
#
# $java
# $java$version
# [1] "1.8.0_171"

# %%
# Elimine la sesión y cierre los navegadores abiertos.
remDr$quit()

# %% [markdown]
# ### Exploración de las funciones de RSelenium

# %% [markdown]
# Para buscar elementos sobre una página iniciando desde la raíz. El elemento localizado podría ser retornado como la un objeto de la clase $webElement$. Las entradas son:
#
# **findElement(using = c("xpath", "css selector", "id", "name", "tag name", "class name", "link text", "partial link text"), value)**

# %% [markdown]
# #### xpath

# %% [markdown]
# Si desea un manual de **xpath** en el siguiente [link](https://www.w3schools.com/xml/xpath_intro.asp)

# %%
# xpath
link = remDr$findElements(using = 'xpath', value = 'html/body//a')

# %%
# Longitu de la lista
length(link)
# Out:
# [1] 464

# %%
# Mostramos todos los link con un for que recorra las listas
vector = c()
contador = 0
for(i in 1:length(link)){
        #print(link[[i]]$getElementAttribute("href")[[1]])
        contador = contador + 1 
       vector[contador] = link[[i]]$getElementAttribute("href")[1]
        
    }
vector
# Out:
# [[1]]
# [1] "https://www.mismarcadores.com/mobile/#android"
#
# [[2]]
# [1] "https://itunes.apple.com/es/app/mismarcadores/id766477515"
#
# [[3]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[4]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[5]]
# [1] "https://www.mismarcadores.com/condiciones/"
#
# [[6]]
# [1] "https://www.mismarcadores.com/"
#
# [[7]]
# [1] "https://www.mismarcadores.com/"
#
# [[8]]
# [1] "https://www.mismarcadores.com/tenis/"
#
# [[9]]
# [1] "https://www.mismarcadores.com/baloncesto/"
#
# [[10]]
# [1] "https://www.mismarcadores.com/golf/"
#
# [[11]]
# [1] "https://www.mismarcadores.com/hockey/"
#
# [[12]]
# [1] "https://www.mismarcadores.com/beisbol/"
#
# [[13]]
# [1] "https://www.mismarcadores.com/balonmano/"
#
# [[14]]
# [1] "https://www.mismarcadores.com/futbol-americano/"
#
# [[15]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[16]]
# [1] "https://www.mismarcadores.com/badminton/"
#
# [[17]]
# [1] "https://www.mismarcadores.com/mma/"
#
# [[18]]
# [1] "https://www.mismarcadores.com/bandy/"
#
# [[19]]
# [1] "https://www.mismarcadores.com/motor/"
#
# [[20]]
# [1] "https://www.mismarcadores.com/boxeo/"
#
# [[21]]
# [1] "https://www.mismarcadores.com/netball/"
#
# [[22]]
# [1] "https://www.mismarcadores.com/carreras-de-caballos/"
#
# [[23]]
# [1] "https://www.mismarcadores.com/pesapallo/"
#
# [[24]]
# [1] "https://www.mismarcadores.com/ciclismo/"
#
# [[25]]
# [1] "https://www.mismarcadores.com/rugby/"
#
# [[26]]
# [1] "https://www.mismarcadores.com/cricket/"
#
# [[27]]
# [1] "https://www.mismarcadores.com/rugby-league/"
#
# [[28]]
# [1] "https://www.mismarcadores.com/dardos/"
#
# [[29]]
# [1] "https://www.mismarcadores.com/snooker/"
#
# [[30]]
# [1] "https://www.mismarcadores.com/deportes-de-invierno/"
#
# [[31]]
# [1] "https://www.mismarcadores.com/tenis-de-mesa/"
#
# [[32]]
# [1] "https://www.mismarcadores.com/esports/"
#
# [[33]]
# [1] "https://www.mismarcadores.com/unihockey/"
#
# [[34]]
# [1] "https://www.mismarcadores.com/futbol-australiano/"
#
# [[35]]
# [1] "https://www.mismarcadores.com/voleibol/"
#
# [[36]]
# [1] "https://www.mismarcadores.com/futbol-playa/"
#
# [[37]]
# [1] "https://www.mismarcadores.com/voley-playa/"
#
# [[38]]
# [1] "https://www.mismarcadores.com/futbol-sala/"
#
# [[39]]
# [1] "https://www.mismarcadores.com/waterpolo/"
#
# [[40]]
# [1] "https://www.mismarcadores.com/hockey-hierba/"
#
# [[41]]
# [1] "https://www.resultados.com/es/"
#
# [[42]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[43]]
# [1] "https://www.mismarcadores.com/futbol/"
#
# [[44]]
# [1] "https://www.mismarcadores.com/futbol/colombia/"
#
# [[45]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/"
#
# [[46]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/"
#
# [[47]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/resultados/"
#
# [[48]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/partidos/"
#
# [[49]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/clasificacion/"
#
# [[50]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/equipos/"
#
# [[51]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/archivo/"
#
# [[52]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/resultados/"
#
# [[53]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/partidos/"
#
# [[54]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/?t=AgYCqMVI&ts=zwN91Swh"
#
# [[55]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/?t=AgYCqMVI&ts=UaMD0ngb"
#
# [[56]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#draw"
#
# [[57]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#top_scorers"
#
# [[58]]
# [1] "javascript:;"
#
# [[59]]
# [1] "javascript:;"
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[75]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[76]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[77]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[78]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[79]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[80]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[81]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[82]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[83]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[84]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/#"
#
# [[85]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/"
#
# [[86]]
# [1] "https://www.mismarcadores.com/futbol/colombia/torneo-aguila/"
#
# [[87]]
# [1] "https://www.mismarcadores.com/futbol/colombia/cuadrangulares-de-ascenso/"
#
# [[88]]
# [1] "https://www.mismarcadores.com/futbol/colombia/copa-aguila/"
#
# [[89]]
# [1] "https://www.mismarcadores.com/futbol/colombia/supercopa/"
#
# [[90]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila-femenina/"
#
# [[91]]
# [1] "https://www.mismarcadores.com/futbol/alemania/bundesliga/"
#
# [[92]]
# [1] "https://www.mismarcadores.com/futbol/espana/laliga/"
#
# [[93]]
# [1] "https://www.mismarcadores.com/futbol/espana/laliga2/"
#
# [[94]]
# [1] "https://www.mismarcadores.com/futbol/francia/ligue-1/"
#
# [[95]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/premier-league/"
#
# [[96]]
# [1] "https://www.mismarcadores.com/futbol/italia/serie-a/"
#
# [[97]]
# [1] "https://www.mismarcadores.com/futbol/europa/champions-league/"
#
# [[98]]
# [1] "https://www.mismarcadores.com/futbol/europa/europa-league/"
#
# [[99]]
# [1] "https://www.mismarcadores.com/futbol/mundial/copa-del-mundo/"
#
# [[100]]
# [1] "https://www.mismarcadores.com/futbol/albania/"
#
# [[101]]
# [1] "https://www.mismarcadores.com/futbol/albania/superliga/"
#
# [[102]]
# [1] "https://www.mismarcadores.com/futbol/alemania/"
#
# [[103]]
# [1] "https://www.mismarcadores.com/futbol/alemania/bundesliga/"
#
# [[104]]
# [1] "https://www.mismarcadores.com/futbol/alemania/2-bundesliga/"
#
# [[105]]
# [1] "https://www.mismarcadores.com/futbol/alemania/3-liga/"
#
# [[106]]
# [1] "https://www.mismarcadores.com/futbol/alemania/dfb-pokal/"
#
# [[107]]
# [1] "https://www.mismarcadores.com/futbol/andorra/"
#
# [[108]]
# [1] "https://www.mismarcadores.com/futbol/angola/"
#
# [[109]]
# [1] "https://www.mismarcadores.com/futbol/angola/girabola-league/"
#
# [[110]]
# [1] "https://www.mismarcadores.com/futbol/arabia-saudi/"
#
# [[111]]
# [1] "https://www.mismarcadores.com/futbol/argelia/"
#
# [[112]]
# [1] "https://www.mismarcadores.com/futbol/argelia/division-1/"
#
# [[113]]
# [1] "https://www.mismarcadores.com/futbol/argentina/"
#
# [[114]]
# [1] "https://www.mismarcadores.com/futbol/argentina/superliga/"
#
# [[115]]
# [1] "https://www.mismarcadores.com/futbol/argentina/torneos-de-verano/"
#
# [[116]]
# [1] "https://www.mismarcadores.com/futbol/armenia/"
#
# [[117]]
# [1] "https://www.mismarcadores.com/futbol/armenia/premier-league/"
#
# [[118]]
# [1] "https://www.mismarcadores.com/futbol/australia/"
#
# [[119]]
# [1] "https://www.mismarcadores.com/futbol/australia/a-league/"
#
# [[120]]
# [1] "https://www.mismarcadores.com/futbol/austria/"
#
# [[121]]
# [1] "https://www.mismarcadores.com/futbol/austria/tipico-bundesliga/"
#
# [[122]]
# [1] "https://www.mismarcadores.com/futbol/austria/erste-liga/"
#
# [[123]]
# [1] "https://www.mismarcadores.com/futbol/austria/ofb-cup/"
#
# [[124]]
# [1] "https://www.mismarcadores.com/futbol/azerbaiyan/"
#
# [[125]]
# [1] "https://www.mismarcadores.com/futbol/bahrein/"
#
# [[126]]
# [1] "https://www.mismarcadores.com/futbol/bangladesh/"
#
# [[127]]
# [1] "https://www.mismarcadores.com/futbol/belgica/"
#
# [[128]]
# [1] "https://www.mismarcadores.com/futbol/belgica/jupiler-pro-league/"
#
# [[129]]
# [1] "https://www.mismarcadores.com/futbol/belgica/proximus-league/"
#
# [[130]]
# [1] "https://www.mismarcadores.com/futbol/belgica/copa/"
#
# [[131]]
# [1] "https://www.mismarcadores.com/futbol/benin/"
#
# [[132]]
# [1] "https://www.mismarcadores.com/futbol/bermudas/"
#
# [[133]]
# [1] "https://www.mismarcadores.com/futbol/bielorrusia/"
#
# [[134]]
# [1] "https://www.mismarcadores.com/futbol/bielorrusia/vysshaya-liga/"
#
# [[135]]
# [1] "https://www.mismarcadores.com/futbol/birmania/"
#
# [[136]]
# [1] "https://www.mismarcadores.com/futbol/bolivia/"
#
# [[137]]
# [1] "https://www.mismarcadores.com/futbol/bolivia/division-profesional/"
#
# [[138]]
# [1] "https://www.mismarcadores.com/futbol/bosnia-y-herzegovina/"
#
# [[139]]
# [1] "https://www.mismarcadores.com/futbol/bosnia-y-herzegovina/premier-league/"
#
# [[140]]
# [1] "https://www.mismarcadores.com/futbol/botswana/"
#
# [[141]]
# [1] "https://www.mismarcadores.com/futbol/brasil/"
#
# [[142]]
# [1] "https://www.mismarcadores.com/futbol/brasil/brasileirao-serie-a/"
#
# [[143]]
# [1] "https://www.mismarcadores.com/futbol/brasil/copa-do-brasil/"
#
# [[144]]
# [1] "https://www.mismarcadores.com/futbol/bulgaria/"
#
# [[145]]
# [1] "https://www.mismarcadores.com/futbol/bulgaria/parva-liga/"
#
# [[146]]
# [1] "https://www.mismarcadores.com/futbol/bulgaria/b-pfg-play-offs/"
#
# [[147]]
# [1] "https://www.mismarcadores.com/futbol/burkina-faso/"
#
# [[148]]
# [1] "https://www.mismarcadores.com/futbol/burundi/"
#
# [[149]]
# [1] "https://www.mismarcadores.com/futbol/cabo-verde/"
#
# [[150]]
# [1] "https://www.mismarcadores.com/futbol/camboya/"
#
# [[151]]
# [1] "https://www.mismarcadores.com/futbol/camerun/"
#
# [[152]]
# [1] "https://www.mismarcadores.com/futbol/canada/"
#
# [[153]]
# [1] "https://www.mismarcadores.com/futbol/canada/liga-csl/"
#
# [[154]]
# [1] "https://www.mismarcadores.com/futbol/qatar/"
#
# [[155]]
# [1] "https://www.mismarcadores.com/futbol/qatar/qatar-stars-league/"
#
# [[156]]
# [1] "https://www.mismarcadores.com/futbol/chile/"
#
# [[157]]
# [1] "https://www.mismarcadores.com/futbol/chile/primera-division/"
#
# [[158]]
# [1] "https://www.mismarcadores.com/futbol/china/"
#
# [[159]]
# [1] "https://www.mismarcadores.com/futbol/china/superliga/"
#
# [[160]]
# [1] "https://www.mismarcadores.com/futbol/chipre/"
#
# [[161]]
# [1] "https://www.mismarcadores.com/futbol/chipre/primera-division/"
#
# [[162]]
# [1] "https://www.mismarcadores.com/futbol/colombia/"
#
# [[163]]
# [1] "https://www.mismarcadores.com/futbol/colombia/liga-aguila/"
#
# [[164]]
# [1] "https://www.mismarcadores.com/futbol/congo/"
#
# [[165]]
# [1] "https://www.mismarcadores.com/futbol/corea-del-sur/"
#
# [[166]]
# [1] "https://www.mismarcadores.com/futbol/corea-del-sur/k-league-1/"
#
# [[167]]
# [1] "https://www.mismarcadores.com/futbol/costa-de-marfil/"
#
# [[168]]
# [1] "https://www.mismarcadores.com/futbol/costa-rica/"
#
# [[169]]
# [1] "https://www.mismarcadores.com/futbol/costa-rica/primera-division/"
#
# [[170]]
# [1] "https://www.mismarcadores.com/futbol/croacia/"
#
# [[171]]
# [1] "https://www.mismarcadores.com/futbol/croacia/1-hnl/"
#
# [[172]]
# [1] "https://www.mismarcadores.com/futbol/dinamarca/"
#
# [[173]]
# [1] "https://www.mismarcadores.com/futbol/dinamarca/superliga/"
#
# [[174]]
# [1] "https://www.mismarcadores.com/futbol/dinamarca/cup/"
#
# [[175]]
# [1] "https://www.mismarcadores.com/futbol/ecuador/"
#
# [[176]]
# [1] "https://www.mismarcadores.com/futbol/ecuador/serie-a/"
#
# [[177]]
# [1] "https://www.mismarcadores.com/futbol/egipto/"
#
# [[178]]
# [1] "https://www.mismarcadores.com/futbol/egipto/premier-league/"
#
# [[179]]
# [1] "https://www.mismarcadores.com/futbol/el-salvador/"
#
# [[180]]
# [1] "https://www.mismarcadores.com/futbol/el-salvador/primera-division/"
#
# [[181]]
# [1] "https://www.mismarcadores.com/futbol/emiratos-arabes-unidos/"
#
# [[182]]
# [1] "https://www.mismarcadores.com/futbol/emiratos-arabes-unidos/uae-league/"
#
# [[183]]
# [1] "https://www.mismarcadores.com/futbol/escocia/"
#
# [[184]]
# [1] "https://www.mismarcadores.com/futbol/escocia/premiership/"
#
# [[185]]
# [1] "https://www.mismarcadores.com/futbol/escocia/championship/"
#
# [[186]]
# [1] "https://www.mismarcadores.com/futbol/escocia/league-one/"
#
# [[187]]
# [1] "https://www.mismarcadores.com/futbol/escocia/league-two/"
#
# [[188]]
# [1] "https://www.mismarcadores.com/futbol/escocia/fa-cup/"
#
# [[189]]
# [1] "https://www.mismarcadores.com/futbol/eslovaquia/"
#
# [[190]]
# [1] "https://www.mismarcadores.com/futbol/eslovaquia/fortuna-liga/"
#
# [[191]]
# [1] "https://www.mismarcadores.com/futbol/eslovenia/"
#
# [[192]]
# [1] "https://www.mismarcadores.com/futbol/eslovenia/prva-liga/"
#
# [[193]]
# [1] "https://www.mismarcadores.com/futbol/espana/"
#
# [[194]]
# [1] "https://www.mismarcadores.com/futbol/espana/laliga/"
#
# [[195]]
# [1] "https://www.mismarcadores.com/futbol/espana/laliga2/"
#
# [[196]]
# [1] "https://www.mismarcadores.com/futbol/espana/copa-del-rey/"
#
# [[197]]
# [1] "https://www.mismarcadores.com/futbol/usa/"
#
# [[198]]
# [1] "https://www.mismarcadores.com/futbol/usa/mls/"
#
# [[199]]
# [1] "https://www.mismarcadores.com/futbol/estonia/"
#
# [[200]]
# [1] "https://www.mismarcadores.com/futbol/estonia/meistriliiga/"
#
# [[201]]
# [1] "https://www.mismarcadores.com/futbol/etiopia/"
#
# [[202]]
# [1] "https://www.mismarcadores.com/futbol/filipinas/"
#
# [[203]]
# [1] "https://www.mismarcadores.com/futbol/finlandia/"
#
# [[204]]
# [1] "https://www.mismarcadores.com/futbol/finlandia/veikkausliiga/"
#
# [[205]]
# [1] "https://www.mismarcadores.com/futbol/finlandia/ykkonen/"
#
# [[206]]
# [1] "https://www.mismarcadores.com/futbol/finlandia/suomen-cup/"
#
# [[207]]
# [1] "https://www.mismarcadores.com/futbol/francia/"
#
# [[208]]
# [1] "https://www.mismarcadores.com/futbol/francia/ligue-1/"
#
# [[209]]
# [1] "https://www.mismarcadores.com/futbol/francia/ligue-2/"
#
# [[210]]
# [1] "https://www.mismarcadores.com/futbol/francia/coupe-de-la-ligue/"
#
# [[211]]
# [1] "https://www.mismarcadores.com/futbol/francia/copa-de-francia/"
#
# [[212]]
# [1] "https://www.mismarcadores.com/futbol/gabon/"
#
# [[213]]
# [1] "https://www.mismarcadores.com/futbol/gales/"
#
# [[214]]
# [1] "https://www.mismarcadores.com/futbol/gales/premier-league/"
#
# [[215]]
# [1] "https://www.mismarcadores.com/futbol/gambia/"
#
# [[216]]
# [1] "https://www.mismarcadores.com/futbol/georgia/"
#
# [[217]]
# [1] "https://www.mismarcadores.com/futbol/georgia/erovnuli-liga/"
#
# [[218]]
# [1] "https://www.mismarcadores.com/futbol/ghana/"
#
# [[219]]
# [1] "https://www.mismarcadores.com/futbol/gibraltar/"
#
# [[220]]
# [1] "https://www.mismarcadores.com/futbol/grecia/"
#
# [[221]]
# [1] "https://www.mismarcadores.com/futbol/grecia/superliga/"
#
# [[222]]
# [1] "https://www.mismarcadores.com/futbol/guatemala/"
#
# [[223]]
# [1] "https://www.mismarcadores.com/futbol/guatemala/liga-nacional/"
#
# [[224]]
# [1] "https://www.mismarcadores.com/futbol/guinea/"
#
# [[225]]
# [1] "https://www.mismarcadores.com/futbol/haiti/"
#
# [[226]]
# [1] "https://www.mismarcadores.com/futbol/holanda/"
#
# [[227]]
# [1] "https://www.mismarcadores.com/futbol/holanda/eredivisie/"
#
# [[228]]
# [1] "https://www.mismarcadores.com/futbol/holanda/jupiler-league/"
#
# [[229]]
# [1] "https://www.mismarcadores.com/futbol/holanda/knvb-beker/"
#
# [[230]]
# [1] "https://www.mismarcadores.com/futbol/honduras/"
#
# [[231]]
# [1] "https://www.mismarcadores.com/futbol/honduras/liga-nacional/"
#
# [[232]]
# [1] "https://www.mismarcadores.com/futbol/hong-kong/"
#
# [[233]]
# [1] "https://www.mismarcadores.com/futbol/hungria/"
#
# [[234]]
# [1] "https://www.mismarcadores.com/futbol/hungria/otp-bank-liga/"
#
# [[235]]
# [1] "https://www.mismarcadores.com/futbol/india/"
#
# [[236]]
# [1] "https://www.mismarcadores.com/futbol/india/isl/"
#
# [[237]]
# [1] "https://www.mismarcadores.com/futbol/india/i-league/"
#
# [[238]]
# [1] "https://www.mismarcadores.com/futbol/indonesia/"
#
# [[239]]
# [1] "https://www.mismarcadores.com/futbol/indonesia/liga-1/"
#
# [[240]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/"
#
# [[241]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/premier-league/"
#
# [[242]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/championship/"
#
# [[243]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/league-one/"
#
# [[244]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/league-two/"
#
# [[245]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/vanarama-national-league/"
#
# [[246]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/fa-cup/"
#
# [[247]]
# [1] "https://www.mismarcadores.com/futbol/inglaterra/carabao-cup/"
#
# [[248]]
# [1] "https://www.mismarcadores.com/futbol/irak/"
#
# [[249]]
# [1] "https://www.mismarcadores.com/futbol/iran/"
#
# [[250]]
# [1] "https://www.mismarcadores.com/futbol/irlanda/"
#
# [[251]]
# [1] "https://www.mismarcadores.com/futbol/irlanda/premier-division/"
#
# [[252]]
# [1] "https://www.mismarcadores.com/futbol/irlanda/fai-cup/"
#
# [[253]]
# [1] "https://www.mismarcadores.com/futbol/irlanda-del-norte/"
#
# [[254]]
# [1] "https://www.mismarcadores.com/futbol/irlanda-del-norte/nifl-premiership/"
#
# [[255]]
# [1] "https://www.mismarcadores.com/futbol/islandia/"
#
# [[256]]
# [1] "https://www.mismarcadores.com/futbol/islandia/pepsideild/"
#
# [[257]]
# [1] "https://www.mismarcadores.com/futbol/islas-feroe/"
#
# [[258]]
# [1] "https://www.mismarcadores.com/futbol/islas-feroe/effodeildin/"
#
# [[259]]
# [1] "https://www.mismarcadores.com/futbol/israel/"
#
# [[260]]
# [1] "https://www.mismarcadores.com/futbol/israel/ligat-ha-al/"
#
# [[261]]
# [1] "https://www.mismarcadores.com/futbol/italia/"
#
# [[262]]
# [1] "https://www.mismarcadores.com/futbol/italia/serie-a/"
#
# [[263]]
# [1] "https://www.mismarcadores.com/futbol/italia/serie-b/"
#
# [[264]]
# [1] "https://www.mismarcadores.com/futbol/italia/coppa-italia/"
#
# [[265]]
# [1] "https://www.mismarcadores.com/futbol/jamaica/"
#
# [[266]]
# [1] "https://www.mismarcadores.com/futbol/japon/"
#
# [[267]]
# [1] "https://www.mismarcadores.com/futbol/japon/j-league/"
#
# [[268]]
# [1] "https://www.mismarcadores.com/futbol/jordania/"
#
# [[269]]
# [1] "https://www.mismarcadores.com/futbol/kazajistan/"
#
# [[270]]
# [1] "https://www.mismarcadores.com/futbol/kenia/"
#
# [[271]]
# [1] "https://www.mismarcadores.com/futbol/kyrgyzstan/"
#
# [[272]]
# [1] "https://www.mismarcadores.com/futbol/kosovo/"
#
# [[273]]
# [1] "https://www.mismarcadores.com/futbol/kuwait/"
#
# [[274]]
# [1] "https://www.mismarcadores.com/futbol/lesotho/"
#
# [[275]]
# [1] "https://www.mismarcadores.com/futbol/letonia/"
#
# [[276]]
# [1] "https://www.mismarcadores.com/futbol/letonia/synottip-virsliga/"
#
# [[277]]
# [1] "https://www.mismarcadores.com/futbol/libano/"
#
# [[278]]
# [1] "https://www.mismarcadores.com/futbol/liberia/"
#
# [[279]]
# [1] "https://www.mismarcadores.com/futbol/libia/"
#
# [[280]]
# [1] "https://www.mismarcadores.com/futbol/liechtenstein/"
#
# [[281]]
# [1] "https://www.mismarcadores.com/futbol/lituania/"
#
# [[282]]
# [1] "https://www.mismarcadores.com/futbol/lituania/a-lyga/"
#
# [[283]]
# [1] "https://www.mismarcadores.com/futbol/luxemburgo/"
#
# [[284]]
# [1] "https://www.mismarcadores.com/futbol/malasia/"
#
# [[285]]
# [1] "https://www.mismarcadores.com/futbol/malasia/super-liga/"
#
# [[286]]
# [1] "https://www.mismarcadores.com/futbol/malawi/"
#
# [[287]]
# [1] "https://www.mismarcadores.com/futbol/maldivas/"
#
# [[288]]
# [1] "https://www.mismarcadores.com/futbol/mali/"
#
# [[289]]
# [1] "https://www.mismarcadores.com/futbol/malta/"
#
# [[290]]
# [1] "https://www.mismarcadores.com/futbol/malta/premier-league/"
#
# [[291]]
# [1] "https://www.mismarcadores.com/futbol/marruecos/"
#
# [[292]]
# [1] "https://www.mismarcadores.com/futbol/marruecos/botola-gnfe1/"
#
# [[293]]
# [1] "https://www.mismarcadores.com/futbol/mauricio/"
#
# [[294]]
# [1] "https://www.mismarcadores.com/futbol/mauritania/"
#
# [[295]]
# [1] "https://www.mismarcadores.com/futbol/mexico/"
#
# [[296]]
# [1] "https://www.mismarcadores.com/futbol/mexico/liga-mx/"
#
# [[297]]
# [1] "https://www.mismarcadores.com/futbol/moldavia/"
#
# [[298]]
# [1] "https://www.mismarcadores.com/futbol/moldavia/division-nacional/"
#
# [[299]]
# [1] "https://www.mismarcadores.com/futbol/montenegro/"
#
# [[300]]
# [1] "https://www.mismarcadores.com/futbol/montenegro/prva-crnogorska-liga/"
#
# [[301]]
# [1] "https://www.mismarcadores.com/futbol/mozambique/"
#
# [[302]]
# [1] "https://www.mismarcadores.com/futbol/namibia/"
#
# [[303]]
# [1] "https://www.mismarcadores.com/futbol/nicaragua/"
#
# [[304]]
# [1] "https://www.mismarcadores.com/futbol/niger/"
#
# [[305]]
# [1] "https://www.mismarcadores.com/futbol/nigeria/"
#
# [[306]]
# [1] "https://www.mismarcadores.com/futbol/noruega/"
#
# [[307]]
# [1] "https://www.mismarcadores.com/futbol/noruega/eliteserien/"
#
# [[308]]
# [1] "https://www.mismarcadores.com/futbol/noruega/obos-ligaen/"
#
# [[309]]
# [1] "https://www.mismarcadores.com/futbol/noruega/nm-cup/"
#
# [[310]]
# [1] "https://www.mismarcadores.com/futbol/nueva-zelanda/"
#
# [[311]]
# [1] "https://www.mismarcadores.com/futbol/oman/"
#
# [[312]]
# [1] "https://www.mismarcadores.com/futbol/pakistan/"
#
# [[313]]
# [1] "https://www.mismarcadores.com/futbol/palestina/"
#
# [[314]]
# [1] "https://www.mismarcadores.com/futbol/panama/"
#
# [[315]]
# [1] "https://www.mismarcadores.com/futbol/paraguay/"
#
# [[316]]
# [1] "https://www.mismarcadores.com/futbol/paraguay/primera-division/"
#
# [[317]]
# [1] "https://www.mismarcadores.com/futbol/peru/"
#
# [[318]]
# [1] "https://www.mismarcadores.com/futbol/peru/torneo-descentralizado/"
#
# [[319]]
# [1] "https://www.mismarcadores.com/futbol/polonia/"
#
# [[320]]
# [1] "https://www.mismarcadores.com/futbol/polonia/ekstraklasa/"
#
# [[321]]
# [1] "https://www.mismarcadores.com/futbol/portugal/"
#
# [[322]]
# [1] "https://www.mismarcadores.com/futbol/portugal/primeira-liga/"
#
# [[323]]
# [1] "https://www.mismarcadores.com/futbol/portugal/segunda-liga/"
#
# [[324]]
# [1] "https://www.mismarcadores.com/futbol/portugal/taca-de-portugal/"
#
# [[325]]
# [1] "https://www.mismarcadores.com/futbol/rd-congo/"
#
# [[326]]
# [1] "https://www.mismarcadores.com/futbol/republica-checa/"
#
# [[327]]
# [1] "https://www.mismarcadores.com/futbol/republica-checa/1-liga/"
#
# [[328]]
# [1] "https://www.mismarcadores.com/futbol/republica-de-macedonia/"
#
# [[329]]
# [1] "https://www.mismarcadores.com/futbol/republica-de-macedonia/prva-liga/"
#
# [[330]]
# [1] "https://www.mismarcadores.com/futbol/republica-dominicana/"
#
# [[331]]
# [1] "https://www.mismarcadores.com/futbol/reunion/"
#
# [[332]]
# [1] "https://www.mismarcadores.com/futbol/ruanda/"
#
# [[333]]
# [1] "https://www.mismarcadores.com/futbol/rumania/"
#
# [[334]]
# [1] "https://www.mismarcadores.com/futbol/rumania/liga-1/"
#
# [[335]]
# [1] "https://www.mismarcadores.com/futbol/rusia/"
#
# [[336]]
# [1] "https://www.mismarcadores.com/futbol/rusia/premier-league/"
#
# [[337]]
# [1] "https://www.mismarcadores.com/futbol/san-marino/"
#
# [[338]]
# [1] "https://www.mismarcadores.com/futbol/senegal/"
#
# [[339]]
# [1] "https://www.mismarcadores.com/futbol/serbia/"
#
# [[340]]
# [1] "https://www.mismarcadores.com/futbol/serbia/super-liga/"
#
# [[341]]
# [1] "https://www.mismarcadores.com/futbol/seychelles/"
#
# [[342]]
# [1] "https://www.mismarcadores.com/futbol/sierra-leona/"
#
# [[343]]
# [1] "https://www.mismarcadores.com/futbol/singapur/"
#
# [[344]]
# [1] "https://www.mismarcadores.com/futbol/singapur/premier-league/"
#
# [[345]]
# [1] "https://www.mismarcadores.com/futbol/siria/"
#
# [[346]]
# [1] "https://www.mismarcadores.com/futbol/somalia/"
#
# [[347]]
# [1] "https://www.mismarcadores.com/futbol/sri-lanka/"
#
# [[348]]
# [1] "https://www.mismarcadores.com/futbol/sudafrica/"
#
# [[349]]
# [1] "https://www.mismarcadores.com/futbol/sudafrica/premier-league/"
#
# [[350]]
# [1] "https://www.mismarcadores.com/futbol/sudan/"
#
# [[351]]
# [1] "https://www.mismarcadores.com/futbol/suecia/"
#
# [[352]]
# [1] "https://www.mismarcadores.com/futbol/suecia/allsvenskan/"
#
# [[353]]
# [1] "https://www.mismarcadores.com/futbol/suecia/superettan/"
#
# [[354]]
# [1] "https://www.mismarcadores.com/futbol/suecia/svenska-cupen/"
#
# [[355]]
# [1] "https://www.mismarcadores.com/futbol/suiza/"
#
# [[356]]
# [1] "https://www.mismarcadores.com/futbol/suiza/super-league/"
#
# [[357]]
# [1] "https://www.mismarcadores.com/futbol/suiza/challenge-league/"
#
# [[358]]
# [1] "https://www.mismarcadores.com/futbol/suiza/swiss-cup/"
#
# [[359]]
# [1] "https://www.mismarcadores.com/futbol/swazilandia/"
#
# [[360]]
# [1] "https://www.mismarcadores.com/futbol/tailandia/"
#
# [[361]]
# [1] "https://www.mismarcadores.com/futbol/tanzania/"
#
# [[362]]
# [1] "https://www.mismarcadores.com/futbol/tayikistan/"
#
# [[363]]
# [1] "https://www.mismarcadores.com/futbol/togo/"
#
# [[364]]
# [1] "https://www.mismarcadores.com/futbol/trinidad-y-tobago/"
#
# [[365]]
# [1] "https://www.mismarcadores.com/futbol/tunez/"
#
# [[366]]
# [1] "https://www.mismarcadores.com/futbol/tunez/ligue-1/"
#
# [[367]]
# [1] "https://www.mismarcadores.com/futbol/turkmenistan/"
#
# [[368]]
# [1] "https://www.mismarcadores.com/futbol/turquia/"
#
# [[369]]
# [1] "https://www.mismarcadores.com/futbol/turquia/super-lig/"
#
# [[370]]
# [1] "https://www.mismarcadores.com/futbol/turquia/tff-1-lig/"
#
# [[371]]
# [1] "https://www.mismarcadores.com/futbol/turquia/copa/"
#
# [[372]]
# [1] "https://www.mismarcadores.com/futbol/ucrania/"
#
# [[373]]
# [1] "https://www.mismarcadores.com/futbol/ucrania/premier-league/"
#
# [[374]]
# [1] "https://www.mismarcadores.com/futbol/uganda/"
#
# [[375]]
# [1] "https://www.mismarcadores.com/futbol/uruguay/"
#
# [[376]]
# [1] "https://www.mismarcadores.com/futbol/uruguay/primera-division/"
#
# [[377]]
# [1] "https://www.mismarcadores.com/futbol/uzbekistan/"
#
# [[378]]
# [1] "https://www.mismarcadores.com/futbol/venezuela/"
#
# [[379]]
# [1] "https://www.mismarcadores.com/futbol/venezuela/primera-division/"
#
# [[380]]
# [1] "https://www.mismarcadores.com/futbol/vietnam/"
#
# [[381]]
# [1] "https://www.mismarcadores.com/futbol/yemen/"
#
# [[382]]
# [1] "https://www.mismarcadores.com/futbol/yibuti/"
#
# [[383]]
# [1] "https://www.mismarcadores.com/futbol/zambia/"
#
# [[384]]
# [1] "https://www.mismarcadores.com/futbol/zimbabwe/"
#
# [[385]]
# [1] "https://www.mismarcadores.com/futbol/africa/"
#
# [[386]]
# [1] "https://www.mismarcadores.com/futbol/africa/copa-de-africa-de-naciones/"
#
# [[387]]
# [1] "https://www.mismarcadores.com/futbol/africa/liga-de-campeones-caf/"
#
# [[388]]
# [1] "https://www.mismarcadores.com/futbol/africa/copa-del-mundo/"
#
# [[389]]
# [1] "https://www.mismarcadores.com/futbol/asia/"
#
# [[390]]
# [1] "https://www.mismarcadores.com/futbol/asia/copa-asiatica/"
#
# [[391]]
# [1] "https://www.mismarcadores.com/futbol/asia/liga-de-campeones-afc/"
#
# [[392]]
# [1] "https://www.mismarcadores.com/futbol/asia/copa-del-mundo/"
#
# [[393]]
# [1] "https://www.mismarcadores.com/futbol/australia-oceania/"
#
# [[394]]
# [1] "https://www.mismarcadores.com/futbol/australia-oceania/copa-del-mundo/"
#
# [[395]]
# [1] "https://www.mismarcadores.com/futbol/europa/"
#
# [[396]]
# [1] "https://www.mismarcadores.com/futbol/europa/eurocopa/"
#
# [[397]]
# [1] "https://www.mismarcadores.com/futbol/europa/champions-league/"
#
# [[398]]
# [1] "https://www.mismarcadores.com/futbol/europa/europa-league/"
#
# [[399]]
# [1] "https://www.mismarcadores.com/futbol/europa/supercopa-uefa/"
#
# [[400]]
# [1] "https://www.mismarcadores.com/futbol/europa/campeonato-de-europa-sub-21/"
#
# [[401]]
# [1] "https://www.mismarcadores.com/futbol/europa/copa-del-mundo/"
#
# [[402]]
# [1] "https://www.mismarcadores.com/futbol/europa/campeonato-de-europa-sub-19/"
#
# [[403]]
# [1] "https://www.mismarcadores.com/futbol/europa/campeonato-de-europa-sub-17/"
#
# [[404]]
# [1] "https://www.mismarcadores.com/futbol/mundial/"
#
# [[405]]
# [1] "https://www.mismarcadores.com/futbol/mundial/copa-del-mundo/"
#
# [[406]]
# [1] "https://www.mismarcadores.com/futbol/mundial/amistosos-internacionales/"
#
# [[407]]
# [1] "https://www.mismarcadores.com/futbol/mundial/amistosos-de-clubs/"
#
# [[408]]
# [1] "https://www.mismarcadores.com/futbol/norte-centroamerica-y-caribe/"
#
# [[409]]
# [1] "https://www.mismarcadores.com/futbol/norte-centroamerica-y-caribe/copa-de-oro/"
#
# [[410]]
# [1] "https://www.mismarcadores.com/futbol/norte-centroamerica-y-caribe/concacaf-liga-de-campeones/"
#
# [[411]]
# [1] "https://www.mismarcadores.com/futbol/norte-centroamerica-y-caribe/copa-del-mundo/"
#
# [[412]]
# [1] "https://www.mismarcadores.com/futbol/sudamerica/"
#
# [[413]]
# [1] "https://www.mismarcadores.com/futbol/sudamerica/copa-america/"
#
# [[414]]
# [1] "https://www.mismarcadores.com/futbol/sudamerica/copa-libertadores/"
#
# [[415]]
# [1] "https://www.mismarcadores.com/futbol/sudamerica/copa-sudamericana/"
#
# [[416]]
# [1] "https://www.mismarcadores.com/futbol/sudamerica/copa-del-mundo/"
#
# [[417]]
# [1] "https://www.mismarcadores.com/links/"
#
# [[418]]
# [1] "https://www.mismarcadores.com/"
#
# [[419]]
# [1] "https://www.mismarcadores.com/tenis/"
#
# [[420]]
# [1] "https://www.mismarcadores.com/baloncesto/"
#
# [[421]]
# [1] "https://www.mismarcadores.com/golf/"
#
# [[422]]
# [1] "https://www.mismarcadores.com/hockey/"
#
# [[423]]
# [1] "https://www.mismarcadores.com/beisbol/"
#
# [[424]]
# [1] "https://www.mismarcadores.com/balonmano/"
#
# [[425]]
# [1] "https://www.mismarcadores.com/futbol-americano/"
#
# [[426]]
# [1] "https://www.mismarcadores.com/voleibol/"
#
# [[427]]
# [1] "https://www.mismarcadores.com/futbol-sala/"
#
# [[428]]
# [1] "https://www.mismarcadores.com/rugby/"
#
# [[429]]
# [1] "https://www.mismarcadores.com/rugby-league/"
#
# [[430]]
# [1] "https://www.mismarcadores.com/unihockey/"
#
# [[431]]
# [1] "https://www.mismarcadores.com/bandy/"
#
# [[432]]
# [1] "https://www.mismarcadores.com/futbol-australiano/"
#
# [[433]]
# [1] "https://www.mismarcadores.com/cricket/"
#
# [[434]]
# [1] "https://www.mismarcadores.com/dardos/"
#
# [[435]]
# [1] "https://www.mismarcadores.com/snooker/"
#
# [[436]]
# [1] "https://www.mismarcadores.com/boxeo/"
#
# [[437]]
# [1] "https://www.mismarcadores.com/voley-playa/"
#
# [[438]]
# [1] "https://www.mismarcadores.com/badminton/"
#
# [[439]]
# [1] "https://www.mismarcadores.com/waterpolo/"
#
# [[440]]
# [1] "https://www.mismarcadores.com/hockey-hierba/"
#
# [[441]]
# [1] "https://www.mismarcadores.com/tenis-de-mesa/"
#
# [[442]]
# [1] "https://www.mismarcadores.com/futbol-playa/"
#
# [[443]]
# [1] "https://www.mismarcadores.com/mma/"
#
# [[444]]
# [1] "https://www.mismarcadores.com/netball/"
#
# [[445]]
# [1] "https://www.mismarcadores.com/pesapallo/"
#
# [[446]]
# [1] "https://www.mismarcadores.com/motor/"
#
# [[447]]
# [1] "https://www.mismarcadores.com/ciclismo/"
#
# [[448]]
# [1] "https://www.mismarcadores.com/carreras-de-caballos/"
#
# [[449]]
# [1] "https://www.mismarcadores.com/esports/"
#
# [[450]]
# [1] "https://www.mismarcadores.com/deportes-de-invierno/"
#
# [[451]]
# [1] "https://www.facebook.com/MisMarcadores"
#
# [[452]]
# [1] "https://plus.google.com/113306182325503484773/"
#
# [[453]]
# [1] "https://twitter.com/mis_marcadores"
#
# [[454]]
# [1] "https://www.mismarcadores.com/mobile/"
#
# [[455]]
# [1] "https://itunes.apple.com/es/app/mismarcadores/id766477515"
#
# [[456]]
# [1] "https://www.mismarcadores.com/mobile/#android"
#
# [[457]]
# [1] "http://t.mismarcadores.com/"
#
# [[458]]
# [1] "http://m.mismarcadores.com/"
#
# [[459]]
# [1] "https://www.mismarcadores.com/condiciones/"
#
# [[460]]
# [1] "https://www.mismarcadores.com/publicidad/"
#
# [[461]]
# [1] "https://www.mismarcadores.com/contactar/"
#
# [[462]]
# [1] "https://www.mismarcadores.com/mobile/"
#
# [[463]]
# [1] "https://www.mismarcadores.com/livescore/"
#
# [[464]]
# [1] "http://www.jugadoresanonimos.org/"

# %%
# Si queremos dar click a uno de los enlaces anteriores
webElement = remDr$findElement(using = 'xpath', value = '//a[@href="/futbol/colombia/liga-aguila/resultados/"]')
webElement
webElement$clickElement()
# Out:
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "3a7dac21-8860-47a6-8004-224623dcdac7"

# %% [markdown]
# #### css selector

# %% [markdown]
# Si desea un manual de **css selector** en el siguiente [link](https://www.w3schools.com/CSSref/css_selectors.asp)

# %%
# Seleccionamos el nodo 'a'
remDr$findElements(using = 'css selector', value = 'a')
# Out:
# [[1]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "749759e1-b0fc-48f8-844c-86f666948414"
#
#
# [[2]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c8129353-5b20-431f-8254-9a34a680e18f"
#
#
# [[3]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "48aea9cd-c240-4adf-9bca-d081d3685307"
#
#
# [[4]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "27d9c5ef-c5b9-4308-975d-3405e6502762"
#
#
# [[5]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "54d2f112-99e3-4d6a-af60-82dfdf901923"
#
#
# [[6]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "556c6ed6-4ce5-471a-acbf-4a2edf2ebb80"
#
#
# [[7]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9f375327-1aa1-4d91-99b7-179caab1828e"
#
#
# [[8]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9819d3f2-0bf8-4f86-8e9b-06c2b8bdda48"
#
#
# [[9]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7dc2982a-5181-408c-9b3d-d23bcb2975b1"
#
#
# [[10]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "108a9256-1522-4425-be89-45c8963f2ffd"
#
#
# [[11]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2349cfa6-c188-43c7-a9e4-cb1731de597b"
#
#
# [[12]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "029d9c88-b8b0-4095-bd62-8704ff00e5ed"
#
#
# [[13]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4f309de9-f9a5-468f-b3c5-2bcec2dd85af"
#
#
# [[14]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4a56fe86-6188-4b40-8c15-7cb1d112d4bd"
#
#
# [[15]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4fb25114-bce2-4f57-9d41-6af99abceca4"
#
#
# [[16]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0e8179b1-487d-45e5-91fc-abe94a5e3360"
#
#
# [[17]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7b59082f-af34-42b2-baf7-3d9902aeb451"
#
#
# [[18]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ebbb6f7a-0f0f-423b-a8ea-d8d8cfd5732c"
#
#
# [[19]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ef31b441-32b9-42ed-9631-3799fd42f457"
#
#
# [[20]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cc22ef82-b376-4166-8ddf-fbbd9406a986"
#
#
# [[21]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d6e9b8f9-8fda-482e-bd37-b932792cec8e"
#
#
# [[22]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "59c2703d-ec06-4367-87ab-4906cbf989e9"
#
#
# [[23]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "1c88ddcd-da7f-4f51-bb27-e1096f625803"
#
#
# [[24]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cda552a5-773d-460b-ad69-3eae359b6891"
#
#
# [[25]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7f567efc-e7ff-49ad-82ce-ab9f3e10e10a"
#
#
# [[26]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "e89dc8c4-6150-4bce-a5a8-b24148dbf743"
#
#
# [[27]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d7be8f4f-631b-4693-9a08-b070b3670e7a"
#
#
# [[28]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ba5a4242-003c-46ed-8fdc-09f7ec6b84be"
#
#
# [[29]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9014b024-1329-4199-ad72-67514b418549"
#
#
# [[30]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "3b9c72dd-8066-41c3-9cd1-11b01aa47023"
#
#
# [[31]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ed251523-2c57-4f8f-9e66-3b7e4b3803f7"
#
#
# [[32]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d4b86fec-02b2-4de7-abaf-c72dd9d2c1b6"
#
#
# [[33]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "91641265-4356-4913-9026-957ed1059bd3"
#
#
# [[34]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0f58c7a2-eea1-4764-9a70-82faf88389c5"
#
#
# [[35]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "404768f7-edec-4748-9f56-8782f8b2f67a"
#
#
# [[36]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "799b165b-6cdd-4d25-8d6f-d8e629e128db"
#
#
# [[37]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9dba983b-8f5c-4271-be19-757c72e5c513"
#
#
# [[38]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "6f93aa39-66a7-4e34-afa5-9665e5e43d5c"
#
#
# [[39]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ac727168-6cb7-4b32-abc7-4c79fa8b35db"
#
#
# [[40]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "42d4461f-2f43-44d5-bdc7-d96cd66f13d7"
#
#
# [[41]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "075e1301-91e4-4cdd-a52b-0ddd0eb21548"
#
#
# [[42]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "133989e4-a7d6-4903-a116-ccdc09e07de1"
#
#
# [[43]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "b77671ca-26fc-4578-bd56-f72a3bf940d4"
#
#
# [[44]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fcc6bc6e-ee8c-41ce-8ab8-26626f5fd5bb"
#
#
# [[45]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "90eb2b56-fb0f-4c0f-b8a2-2ca9aa82f15f"
#
#
# [[46]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "393b4af0-4b8c-4904-bf92-25e876981d42"
#
#
# [[47]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "f80c398c-82ad-4266-a6d7-7b925e32cf96"
#
#
# [[48]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "23515b33-9805-4799-90db-c25ee3c40fa6"
#
#
# [[49]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "095aa179-5e19-479e-8c07-c9caf4b6e1ab"
#
#
# [[50]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "37976ec3-2bdf-4534-82ff-5485ef85b9c5"
#
#
# [[51]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "254460bd-1567-4bfa-82b3-fcd33ce41c6e"
#
#
# [[52]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "eb179a99-767f-4520-9fd3-6e889dca9a61"
#
#
# [[53]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "124dbb30-4db1-4522-8c5a-a11c425a438d"
#
#
# [[54]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "dbcaf2a2-b40f-4e3e-ba4e-7118d219db60"
#
#
# [[55]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9bd7b287-69e2-425d-a828-2b4eba98a6ea"
#
#
# [[56]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0d7c5547-c678-475f-b231-4298a94937d4"
#
#
# [[57]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c625d1ea-0651-42c7-b36c-afd719af750c"
#
#
# [[58]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cd341b20-0141-4e86-ab68-4764c680dd4c"
#
#
# [[59]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "abd36ddc-e1a1-4c28-9f90-42b4e5be896b"
#
#
# [[60]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "42bbb5aa-f317-4445-af62-aa0d54e00632"
#
#
# [[61]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "38c408a5-4180-41c7-a6d2-31e5363273c3"
#
#
# [[62]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9a763914-125b-48fc-b90d-c3663fdc8083"
#
#
# [[63]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "29c6189e-331e-4844-b6d9-7b5d98ad2f90"
#
#
# [[64]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fb8d44b9-852c-4ac5-a14c-192076ff3f50"
#
#
# [[65]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "bb84d850-8252-4ad1-9b17-eb3e4fada04c"
#
#
# [[66]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "acef60de-9763-44e6-819f-4a0b0013d53d"
#
#
# [[67]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "47e54dfa-4922-4ca8-84f9-b9d7031b772c"
#
#
# [[68]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2b9beb2e-852b-487f-992d-eba99344194d"
#
#
# [[69]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "38d572e6-fac6-4c4e-87af-fbe0175fc609"
#
#
# [[70]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "3c445b05-0087-423c-aa88-8a006ab1284e"
#
#
# [[71]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2b2bdb29-9b09-4e0b-9e8d-ff35d0dcf755"
#
#
# [[72]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "6775ba98-1fca-455f-ac6d-6bd9a4631647"
#
#
# [[73]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "703f98fb-a0fe-49f3-a318-94376e240034"
#
#
# [[74]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a44e6e80-b162-4bdc-a48f-218b86c04540"
#
#
# [[75]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "3a45a502-c742-4875-bf7b-fa96fddd2247"
#
#
# [[76]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0a9ca025-ea49-4ea8-8ceb-340b98572efe"
#
#
# [[77]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "22bbba6d-0625-4ecb-a433-6c29af748972"
#
#
# [[78]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4e58f817-8808-48d7-97a6-d730f37e6be0"
#
#
# [[79]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "aaba57d2-28be-42e4-8b6f-b8c62a2c5b34"
#
#
# [[80]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "f3369f72-0fb8-496b-b3e6-50b895d6de54"
#
#
# [[81]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "8c875a96-f360-44b8-bd8c-21ede60b065f"
#
#
# [[82]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "b0206bb3-eb1a-4c09-991f-f9feba36e6e7"
#
#
# [[83]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "eec404a7-5e05-4b50-879a-a64e59aef7a3"
#
#
# [[84]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "07c2ea4c-60ad-4962-b3ee-02c2de5717d5"
#
#
# [[85]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fcef7a80-09ef-491c-a068-86b4d8937dd0"
#
#
# [[86]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "6303967a-ca0e-42e4-9dcf-a15e88945b3c"
#
#
# [[87]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "bbcbe644-40aa-4d54-84cf-5ee28131d7e8"
#
#
# [[88]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "65fb3236-7e50-47b3-accc-895b0f75bc26"
#
#
# [[89]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "b3951fa0-de34-4c99-99d2-bcdbe09a7c6d"
#
#
# [[90]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "035f2cef-cb0a-4033-9f63-63d80d3609ff"
#
#
# [[91]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cebd89e6-93ee-4487-b4d2-2d94f3b5daf6"
#
#
# [[92]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "dd4b919d-ec64-484b-b078-2c177c91011f"
#
#
# [[93]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "dc516ae4-6c17-449c-9d81-1d68dafe2c33"
#
#
# [[94]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2f231c64-e7de-4ad7-bee2-a1f911389ece"
#
#
# [[95]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "37274bf2-965c-4505-8430-595b8013800e"
#
#
# [[96]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4a958cc4-89eb-4ffc-b37b-7642cc843cf1"
#
#
# [[97]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "438c5934-de6e-4eb1-9a41-c149febebde5"
#
#
# [[98]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "8015db18-1d3c-45b5-b430-a69184fa180d"
#
#
# [[99]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "05c10511-5dd2-47a8-bd28-e151bcd14f40"
#
#
# [[100]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9b3f029c-1890-463b-89da-77023882861c"
#
#
# [[101]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "42dda3ae-a736-4040-b489-53d208d6095a"
#
#
# [[102]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "01436f20-87f3-45ad-bc88-f5b6f78f0bfb"
#
#
# [[103]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "00fc80c7-f2a0-4c72-acdb-8f87c77b4d41"
#
#
# [[104]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "11daefed-bc61-41af-b392-a7b19a2b3b3a"
#
#
# [[105]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fd75e6ee-4495-46a4-9ef1-5f6bbfcdbcf6"
#
#
# [[106]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9d70afe9-1b70-4172-87a2-b66bdb0df207"
#
#
# [[107]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "76c5157d-05fc-44cb-b062-184c77f3f935"
#
#
# [[108]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "3ff771ff-278f-46fe-9955-e2196fa18a97"
#
#
# [[109]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a7220d55-18d1-4d16-a6a5-6ff8da352e51"
#
#
# [[110]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0f6c3218-025b-48eb-8676-cbb309091acb"
#
#
# [[111]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7190d08a-2313-4c9d-83de-4527581ec82f"
#
#
# [[112]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c6be4690-7bad-4762-889d-77e9ba367647"
#
#
# [[113]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "dbe49b29-4909-4342-87df-118c507f4f45"
#
#
# [[114]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2101a486-976b-4b2e-8407-f47712baa3c3"
#
#
# [[115]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "8eee5d7b-d141-4b1d-a328-38877622daf2"
#
#
# [[116]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "e79b844b-5f7a-4140-8f1c-64638e0451a6"
#
#
# [[117]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cc7accc7-0847-49a5-8737-5d837f770454"
#
#
# [[118]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0051654b-d293-4173-95b1-965aa53b0c9b"
#
#
# [[119]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4f414440-4bae-4e2f-aed7-f1f0f2fd9314"
#
#
# [[120]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "e3abe5d2-4175-4292-abaa-9d781d80cbbb"
#
#
# [[121]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "6335243c-4069-49a0-865e-b544f58e7f3d"
#
#
# [[122]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0460dff6-2659-4e09-b35e-997c96ded675"
#
#
# [[123]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "24320a97-98b7-4159-99bb-0eb43134103a"
#
#
# [[124]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4531ab5e-1aa7-46d8-b395-ccea01c087cb"
#
#
# [[125]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2fec4ccf-f002-4c5d-a38b-c3d72f34edc5"
#
#
# [[126]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a625cf7b-9da1-4997-a046-c1f23fb5c072"
#
#
# [[127]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "586c3743-fecc-4350-b652-7d6a84bedafd"
#
#
# [[128]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d42cc70f-ba28-4080-bbd2-07fa7a368ec0"
#
#
# [[129]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "450966ce-0896-4373-9975-5a14ff63eb56"
#
#
# [[130]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d115036e-6be8-4a3d-b341-8829d64ea95a"
#
#
# [[131]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "45ec8bb7-423c-46c6-a192-1583070f6f15"
#
#
# [[132]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "dc43b912-d429-41b8-be6a-6d1a0fa05bed"
#
#
# [[133]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2a7885f3-d343-4944-b6af-53e629d4e17f"
#
#
# [[134]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "797154b6-dea4-4ff2-b02f-ca34e1310a0f"
#
#
# [[135]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "1ab3a31d-f2a5-4a20-bc9d-bc66b13c7133"
#
#
# [[136]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "8fd17965-7443-4f3b-8534-7a92d7ce8080"
#
#
# [[137]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "42d607a7-d698-43e0-aa3b-27b993525680"
#
#
# [[138]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "5533a29f-08f5-49cd-81d6-dd02ffbecca2"
#
#
# [[139]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d812d843-ffae-401b-afe8-53a36830068a"
#
#
# [[140]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c944577f-a811-4407-995c-b9115cbd185a"
#
#
# [[141]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "abd5bb33-bcc5-4b4f-bc5e-82b621602b87"
#
#
# [[142]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "f3059e78-82ce-4dbe-9553-9185ff5d531c"
#
#
# [[143]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a5fc448c-708d-451e-bb1b-5125a2e51b83"
#
#
# [[144]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "63e0ebed-912f-4586-abd7-3f7998d8ebb0"
#
#
# [[145]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "73eccc4b-4d55-4fbd-b0b3-fa65c33f6fe3"
#
#
# [[146]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c64779f4-c0c4-4a61-8bbf-06b6b7270f5e"
#
#
# [[147]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "eb269ea8-23a2-48ab-9fab-9acbd4541d2f"
#
#
# [[148]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ec42bd6a-cc2e-44ee-b536-fbc590f26d84"
#
#
# [[149]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "f0494c93-84b0-4a4e-a13a-61748964bab0"
#
#
# [[150]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c87547e2-030b-410d-9cd3-b3b4a2bf6c9f"
#
#
# [[151]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "f36720db-9fec-4951-b97b-8520639c0508"
#
#
# [[152]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0fc7d977-d3d0-45cb-97c8-ad591cdd562d"
#
#
# [[153]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "14e0c26b-bf1d-4c30-bfe1-6ab298f1c6d0"
#
#
# [[154]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ec972e1e-2c4b-4829-b9c0-9e649514e4e9"
#
#
# [[155]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d31e883d-fef3-4900-95e2-61b9c0b390c7"
#
#
# [[156]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "22cab35f-7d62-4142-b2f3-c02315884917"
#
#
# [[157]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fd52d5e6-664c-4a56-81b7-33a28ff64230"
#
#
# [[158]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9909f64d-cbf2-4da8-a8ff-964711ef44c0"
#
#
# [[159]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# ...
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d584d107-213c-4ce3-8dd8-c51d9e362d2d"
#
#
# [[390]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "52d683ac-49e3-4c63-9da5-f4ccab3057d0"
#
#
# [[391]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "5a8b1abe-5aeb-4874-a305-007c82027abc"
#
#
# [[392]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "36d6057d-bb9f-47ad-9289-9f24fd4b58ca"
#
#
# [[393]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d345f1c5-2822-43df-a8e3-ace141b3bcfa"
#
#
# [[394]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c3e130e4-2bbb-41a3-a1d8-33090588c5c9"
#
#
# [[395]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cad94e2d-003d-42bc-9b82-efdd7f02e3fa"
#
#
# [[396]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7dec1c25-df54-4b49-a2e7-8c570ca940c6"
#
#
# [[397]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c8ab80ca-05f9-4ea0-835b-5cb34f7305b3"
#
#
# [[398]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "2c679dd4-e513-4a50-8419-c454fe14a77d"
#
#
# [[399]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7787cc4c-2e12-492e-811f-267c13038603"
#
#
# [[400]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "15d6f44c-fd69-4cdd-85ac-cbc7cd5573f1"
#
#
# [[401]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "4191330e-49bd-4ce8-b7e3-8f9fa1453caa"
#
#
# [[402]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "35a29102-ceca-496c-a809-447360d792c4"
#
#
# [[403]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "436cb393-bcac-4af1-baa8-566c42d2c05f"
#
#
# [[404]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "18ec87ba-c4fd-4a74-8b69-cbc4852ae768"
#
#
# [[405]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "00cb533e-0def-40e1-b325-5898d6ec565e"
#
#
# [[406]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "1a9ab476-4862-4cc3-9920-d0197f60b73b"
#
#
# [[407]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "719560b6-1056-4139-9f7f-4bf026d4f03b"
#
#
# [[408]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a658440d-75ca-4b96-b2b7-44ff3effd17e"
#
#
# [[409]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ac6a1ea6-2377-4382-84fe-7942f8f6334f"
#
#
# [[410]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "297fe0b2-f2fe-4bdc-8ee2-c96193b484ef"
#
#
# [[411]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "e376504e-d4df-4ef1-8a2b-761ac029a414"
#
#
# [[412]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "bc7dc4f1-8720-40c3-a578-6d88106a2502"
#
#
# [[413]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ea0bcd92-fddd-4e56-9bbd-272c5c201540"
#
#
# [[414]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "18b537be-e5e0-4ebf-9be8-2e9915b52fc0"
#
#
# [[415]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "73441d9b-0efe-4026-9141-c70b19f2cbcf"
#
#
# [[416]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "cc87d5e2-2574-4627-8eb6-e636f2f0c146"
#
#
# [[417]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0d861f42-4b9d-45f0-a059-fd0118223208"
#
#
# [[418]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "b472f55b-4941-4b2e-b218-2cb3458557fc"
#
#
# [[419]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "1c17d340-26e3-484b-b375-96dc5563f971"
#
#
# [[420]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "5a5d4c54-65c7-4ba9-b7aa-eb22fc60f791"
#
#
# [[421]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "23f47be1-e55b-4436-890f-8f7a9e2e6e49"
#
#
# [[422]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9b354a77-8717-4183-ab93-6cc54753db5f"
#
#
# [[423]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0b3df468-460e-421b-979d-b3da54846cea"
#
#
# [[424]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d715e905-9e59-4228-b317-9d2b81adffff"
#
#
# [[425]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "54cf75f0-c670-4f35-a118-4c25585e7011"
#
#
# [[426]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "a1ba5760-6a41-4c5b-982f-7bde9ee7fde0"
#
#
# [[427]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "c88ffd97-039f-4482-896e-0cb8d03dd974"
#
#
# [[428]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "9db0b79d-7935-4a74-acd0-fe8609b77791"
#
#
# [[429]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "0b061abe-a361-4df5-a21c-083e24049cd3"
#
#
# [[430]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fe7fe963-2f97-4d95-9e8e-0a1aeb3fa4be"
#
#
# [[431]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "5218fdc2-ff86-490e-b000-e1bad6b22818"
#
#
# [[432]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "5acf7368-e4ed-4b78-bd55-9c21fbb08933"
#
#
# [[433]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "df36aafd-172d-4daa-a69b-25f6efbab222"
#
#
# [[434]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7e3d9fec-c8f3-44fd-b9fd-8bbb3a837de3"
#
#
# [[435]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "703556e5-57d8-41b9-8980-b19050030500"
#
#
# [[436]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "7480f6f3-0469-4395-9dea-0405663dfa35"
#
#
# [[437]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "83d0988a-c239-4be8-bf7a-b58e9c5171b8"
#
#
# [[438]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "d61ce0f8-91ab-4870-b328-dfb8720f1772"
#
#
# [[439]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "751afdee-b3f6-4f68-a3b8-19c5c3656116"
#
#
# [[440]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "fa181a26-7f11-4403-8b6f-5e10fe99e503"
#
#
# [[441]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "74c62e47-4fe1-460e-a7e1-8257566497f0"

# %%
# Seleccionamos el nodo 'p'
remDr$findElements(using = "css selector", value = "p")
# Out:
# list()

# %%
# Selecciona el id = mt
remDr$findElements(using = "css selector", value = "#mt")
# Out:
# [[1]]
# [1] "remoteDriver fields"
# $remoteServerAddr
# [1] "localhost"
#
# $port
# [1] 4444
#
# $browserName
# [1] "firefox"
#
# $version
# [1] ""
#
# $platform
# [1] "ANY"
#
# $javascript
# [1] TRUE
#
# $nativeEvents
# [1] TRUE
#
# $extraCapabilities
# list()
#
# [1] "webElement fields"
# $elementId
# [1] "ad52c933-ce4e-4f83-bb52-1088b5a48158"
